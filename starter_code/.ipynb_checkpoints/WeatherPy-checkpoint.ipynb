# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# # observable trends
#
# After collecting weather data from more than 500 random and diverse cities around the world using the OpenWeatherMap API, which was collected on November 7 2020, the data illustrated maximum temperature (in Celcius), humidity (%), cloudiness (%) and wind speed (mph) with the corresponding city, and with respect to the geo-coordinate, Latitude.
#
# It's with no suprise that temperatures are higher closer to the Equator (at 0° Latitude) and are much lower in the Northern Hemisphere as winter is starting because of high latitudes, and therefore receive less direct sunlight in the winter and become colder.
#
# It is also important to note that temperatures peak at around  -15° to -25°Latitude with with an average temperature of about 32°c, and drop slightly further into the Southern Hemisphere (at -40° Latitude and below),close to the South Pole. This data obtained on  temperature is the result of seasons and the movement of the Earth around the Sun.
#
# Throughout the year the northern and southern hemispheres are alternately turned either toward or away from the sun depending on Earth's position in its orbit. The hemisphere facing the sun receives more sunlight and is in summer, while the other hemisphere receives less sun and is in winter.
#
# There's little to no apparent correlation between humidity and Latitude and cloudiness and Latitude. The scatter plot display a considerable amount of heterogeneity even at similar Latitudes. However, a small grouping of cities show low humity levels (at 0% humidity) in both Hemishperes.
#
# As for wind Speed and Latitude, wind speeds increase in the upper and lower halves on the hemisphere, especially in the north (around 55° to 70° Latitude), and do not go above 10mph within 30° of the Equator.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint
import json


# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Get the Weather data
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

weather_response = requests.get(query_url + city)
weather_json = weather_response.json()

#print(json.dumps(weather_json, indent=4))
#print(requests.get(query_url+city))

# Set Up Lists to Hold Reponse Info
city_name = []
latitude= []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# Processing Record Counter Starting a 1
processing_record = 1

# Print Starting Log Statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

# Loop Through List of Cities & Perform a Request for Data on Each
for city in cities:
   
     
# Exception Handling
    try:
        response = requests.get(query_url+ city).json()
        city_name.append(response["name"])
        latitude.append(response["coord"]["lat"])
        longitude.append(response["coord"]["lon"])
        max_temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed.append(response["wind"]["speed"])
        country.append(response["sys"]["country"])
        date.append(pd.to_datetime(response["dt"],unit='s'))
        current_city = response["name"]
        print(f"Processing Record {processing_record}| {current_city}")
    
        # Increase Processing Record Counter by 1 For Each Loop
        processing_record += 1
          
    except:
        print("City not found next ...") 
    continue

# Print Ending Log Statement
print(f"-------------------------------")
print(f"Data Retrieval Complete")
print(f"-------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1| Villazón
# Processing Record 2| Bengkulu
# Processing Record 3| Ancud
# Processing Record 4| Jamestown
# Processing Record 5| Hamilton
# Processing Record 6| San Patricio
# Processing Record 7| Mataura
# City not found next ...
# Processing Record 8| Half Moon Bay
# City not found next ...
# Processing Record 9| Cherskiy
# Processing Record 10| Hvide Sande
# Processing Record 11| Ushuaia
# Processing Record 12| Avarua
# City not found next ...
# Processing Record 13| Sinnamary
# City not found next ...
# Processing Record 14| Mar del Plata
# Processing Record 15| Katangli
# Processing Record 16| Cidreira
# Processing Record 17| Bosaso
# Processing Record 18| Alofi
# Processing Record 19| Tasiilaq
# Processing Record 20| Kautokeino
# Processing Record 21| Gorahun
# Processing Record 22| Port Alfred
# Processing Record 23| Comodoro Rivadavia
# Processing Record 24| Sioux Lookout
# Processing Record 25| Padang
# Processing Record 26| Saint Anthony
# Processing Record 27| Klaksvík
# Processing Record 28| Hermanus
# Processing Record 29| Salalah
# Processing Record 30| Rawson
# Processing Record 31| Chu
# Processing Record 32| Harper
# Processing Record 33| Kemijärvi
# Processing Record 34| Mount Gambier
# Processing Record 35| Busselton
# Processing Record 36| Oksbøl
# Processing Record 37| Samarai
# Processing Record 38| Tiksi
# Processing Record 39| Saldanha
# Processing Record 40| Port Moresby
# Processing Record 41| Tumbagaan
# Processing Record 42| Vaini
# Processing Record 43| Saint Paul Harbor
# Processing Record 44| Kuragino
# Processing Record 45| Desaguadero
# Processing Record 46| Barrow
# Processing Record 47| Valle de Allende
# Processing Record 48| Chokurdakh
# City not found next ...
# Processing Record 49| Carnarvon
# Processing Record 50| Mokobeng
# Processing Record 51| Saint-Louis
# Processing Record 52| Valdivia
# Processing Record 53| Taoudenni
# Processing Record 54| Bongandanga
# City not found next ...
# Processing Record 55| Hilo
# Processing Record 56| Hithadhoo
# Processing Record 57| Rikitea
# City not found next ...
# Processing Record 58| Torbay
# Processing Record 59| Ostrovnoy
# Processing Record 60| Leh
# Processing Record 61| Sittwe
# Processing Record 62| Souillac
# Processing Record 63| Pokosnoye
# Processing Record 64| Nikolskoye
# Processing Record 65| São Filipe
# Processing Record 66| Sarkand
# Processing Record 67| Hobart
# Processing Record 68| Port-Gentil
# Processing Record 69| Gondanglegi
# Processing Record 70| Paramonga
# Processing Record 71| Auki
# Processing Record 72| Selenginsk
# Processing Record 73| Port Hardy
# City not found next ...
# City not found next ...
# Processing Record 74| Te Anau
# Processing Record 75| Albany
# Processing Record 76| Arraial do Cabo
# Processing Record 77| Derzhavīnsk
# Processing Record 78| Arys
# Processing Record 79| Srednekolymsk
# Processing Record 80| Khatanga
# Processing Record 81| Dikson
# Processing Record 82| Cape Town
# Processing Record 83| Shahreza
# Processing Record 84| Chui
# Processing Record 85| Sechura
# Processing Record 86| Puro
# Processing Record 87| Ilulissat
# Processing Record 88| Dingle
# Processing Record 89| Bredasdorp
# Processing Record 90| Upernavik
# Processing Record 91| Ribeira Grande
# City not found next ...
# Processing Record 92| Flinders
# Processing Record 93| Qui Nhon
# Processing Record 94| Castro
# Processing Record 95| Bluff
# City not found next ...
# Processing Record 96| George Town
# Processing Record 97| Provideniya
# Processing Record 98| Gōtsuchō
# Processing Record 99| Bambous Virieux
# Processing Record 100| New Norfolk
# Processing Record 101| Mangalore
# Processing Record 102| Airai
# Processing Record 103| Uray
# Processing Record 104| Longyearbyen
# Processing Record 105| Saskylakh
# Processing Record 106| Bubaque
# City not found next ...
# Processing Record 107| Santana
# Processing Record 108| Yellowknife
# Processing Record 109| Port Elizabeth
# Processing Record 110| Dabakala
# Processing Record 111| Sīra
# Processing Record 112| Yarmouth
# Processing Record 113| Lebu
# Processing Record 114| Ongandjera
# City not found next ...
# Processing Record 115| Iberia
# Processing Record 116| Thompson
# Processing Record 117| Cockburn Town
# Processing Record 118| Hay River
# Processing Record 119| Nur
# Processing Record 120| Darhan
# Processing Record 121| Bethel
# Processing Record 122| Kholtoson
# Processing Record 123| Aranos
# Processing Record 124| Toktogul
# Processing Record 125| Punta Arenas
# Processing Record 126| Olafsvik
# Processing Record 127| Paamiut
# Processing Record 128| San Julián
# Processing Record 129| Mahébourg
# Processing Record 130| Pemangkat
# Processing Record 131| Belmonte
# Processing Record 132| Iqaluit
# Processing Record 133| Mabaruma
# Processing Record 134| Preobrazheniye
# Processing Record 135| Hasaki
# Processing Record 136| Buala
# Processing Record 137| Lomita
# Processing Record 138| Waingapu
# Processing Record 139| Bull Savanna
# Processing Record 140| Barra de Tecoanapa
# Processing Record 141| Pevek
# Processing Record 142| Smirnykh
# Processing Record 143| Guerrero Negro
# City not found next ...
# City not found next ...
# Processing Record 144| Loukhi
# Processing Record 145| Binga
# Processing Record 146| Novozaimka
# Processing Record 147| Nsanje
# Processing Record 148| Nioro
# Processing Record 149| Saint-Philippe
# Processing Record 150| Tuktoyaktuk
# Processing Record 151| La Ronge
# Processing Record 152| Atar
# Processing Record 153| Dengzhou
# Processing Record 154| Vyyezdnoye
# Processing Record 155| Ulverstone
# Processing Record 156| Apastovo
# Processing Record 157| Terra Santa
# Processing Record 158| Bambanglipuro
# Processing Record 159| Inhambane
# Processing Record 160| Kahului
# Processing Record 161| Clyde River
# Processing Record 162| Weligama
# Processing Record 163| Pingdu
# Processing Record 164| Singapore
# Processing Record 165| Letlhakane
# Processing Record 166| Talara
# City not found next ...
# Processing Record 167| Mayen
# Processing Record 168| Tual
# Processing Record 169| Butaritari
# Processing Record 170| Sitārganj
# Processing Record 171| Jérémie
# Processing Record 172| Vila Velha
# Processing Record 173| Faya
# Processing Record 174| Coquimbo
# City not found next ...
# Processing Record 175| Majene
# Processing Record 176| Taungdwingyi
# Processing Record 177| Kaeo
# Processing Record 178| Dunedin
# Processing Record 179| Demyansk
# Processing Record 180| Hambantota
# Processing Record 181| Saint-Augustin
# Processing Record 182| Kununurra
# Processing Record 183| Jiazi
# Processing Record 184| Fortuna
# Processing Record 185| Texarkana
# Processing Record 186| Butka
# Processing Record 187| Tambo Grande
# Processing Record 188| Lüderitz
# Processing Record 189| Laas
# Processing Record 190| Cabrero
# Processing Record 191| Kaitangata
# Processing Record 192| Kibara
# Processing Record 193| Mâncio Lima
# Processing Record 194| Aykhal
# Processing Record 195| Mykhaylivka
# Processing Record 196| Vila Franca do Campo
# Processing Record 197| Naze
# City not found next ...
# Processing Record 198| Tessalit
# Processing Record 199| Abalak
# Processing Record 200| Piaçabuçu
# Processing Record 201| Seddon
# Processing Record 202| Port Blair
# Processing Record 203| Shevchenkove
# Processing Record 204| Codrington
# Processing Record 205| Yārāda
# Processing Record 206| Belaguntha
# Processing Record 207| Gisborne
# Processing Record 208| Asău
# Processing Record 209| Luanda
# Processing Record 210| Diffa
# Processing Record 211| Eureka
# Processing Record 212| Muhafazat Lahij
# Processing Record 213| El Dorado
# Processing Record 214| Mossamedes
# Processing Record 215| Tilichiki
# Processing Record 216| Hualmay
# Processing Record 217| Norman Wells
# Processing Record 218| Grado
# Processing Record 219| Esperance
# Processing Record 220| Ponta do Sol
# Processing Record 221| Kokopo
# Processing Record 222| Jacksonville
# Processing Record 223| Port Hawkesbury
# Processing Record 224| Praia
# Processing Record 225| Lompoc
# Processing Record 226| Burlatskoye
# Processing Record 227| Avera
# Processing Record 228| Ocean City
# Processing Record 229| Vao
# Processing Record 230| Deputatsky
# Processing Record 231| Aklavik
# Processing Record 232| Puerto Ayora
# City not found next ...
# Processing Record 233| Yanam
# City not found next ...
# Processing Record 234| Bundaberg
# Processing Record 235| Newport
# Processing Record 236| Kapaa
# Processing Record 237| Portland
# Processing Record 238| Hong Kong
# Processing Record 239| Saint George
# Processing Record 240| Haines Junction
# Processing Record 241| Talcahuano
# Processing Record 242| Hohhot
# Processing Record 243| Mount Isa
# Processing Record 244| Kiama
# Processing Record 245| Hofn
# Processing Record 246| Kang
# Processing Record 247| Atuona
# Processing Record 248| Qaanaaq
# Processing Record 249| Chumikan
# Processing Record 250| Usinsk
# Processing Record 251| Irpa Irpa
# Processing Record 252| Makakilo City
# City not found next ...
# Processing Record 253| Mehamn
# Processing Record 254| Mahabalipuram
# Processing Record 255| Marawi
# Processing Record 256| Krasnoarmeysk
# Processing Record 257| Gravelbourg
# City not found next ...
# Processing Record 258| Nome
# Processing Record 259| Lima
# Processing Record 260| Sitka
# Processing Record 261| Umluj
# Processing Record 262| Turaif
# Processing Record 263| East London
# Processing Record 264| Ahipara
# Processing Record 265| Kawalu
# Processing Record 266| Taseyevo
# Processing Record 267| Shenkursk
# Processing Record 268| Marapanim
# Processing Record 269| Wajima
# Processing Record 270| The Valley
# City not found next ...
# Processing Record 271| Altay
# Processing Record 272| Yumen
# Processing Record 273| Beloha
# Processing Record 274| Batagay-Alyta
# Processing Record 275| Linguère
# Processing Record 276| Sühbaatar
# Processing Record 277| Rundu
# Processing Record 278| Salina
# Processing Record 279| Tura
# Processing Record 280| Caucayá
# Processing Record 281| Kavaratti
# City not found next ...
# Processing Record 282| Olinda
# Processing Record 283| Koryukivka
# Processing Record 284| Alexandria
# Processing Record 285| Puerto Colombia
# Processing Record 286| Khovd
# Processing Record 287| Marck
# Processing Record 288| Laguna
# Processing Record 289| Río Gallegos
# Processing Record 290| Polovinnoye
# Processing Record 291| Praia da Vitória
# Processing Record 292| Grand Gaube
# Processing Record 293| Goālpāra
# Processing Record 294| Doha
# Processing Record 295| Quatre Cocos
# Processing Record 296| Vilhena
# Processing Record 297| Necochea
# Processing Record 298| Baykalovo
# Processing Record 299| Grindavik
# Processing Record 300| Tobol
# Processing Record 301| Panjakent
# Processing Record 302| Saint-Joseph
# Processing Record 303| Margate
# City not found next ...
# Processing Record 304| Kidal
# Processing Record 305| Saint-Pierre
# Processing Record 306| Boddam
# Processing Record 307| Tuatapere
# City not found next ...
# Processing Record 308| Kattivākkam
# Processing Record 309| Kavieng
# Processing Record 310| Inta
# Processing Record 311| Bonavista
# Processing Record 312| Sept-Îles
# Processing Record 313| Geraldton
# Processing Record 314| Kieta
# Processing Record 315| San Cristobal
# Processing Record 316| Black Diamond
# Processing Record 317| Verkhnyaya Inta
# Processing Record 318| Zhigansk
# Processing Record 319| Presidencia Roque Sáenz Peña
# Processing Record 320| Bayan
# Processing Record 321| Maceió
# Processing Record 322| Petropavlovsk-Kamchatskiy
# Processing Record 323| Isangel
# Processing Record 324| Palauig
# Processing Record 325| Tsabong
# Processing Record 326| Seymchan
# Processing Record 327| Mendi
# Processing Record 328| Saravan
# Processing Record 329| Khuchni
# Processing Record 330| Khartoum
# Processing Record 331| Vuyyūru
# Processing Record 332| Falam
# Processing Record 333| Genhe
# Processing Record 334| Lahaina
# Processing Record 335| Tres Picos
# Processing Record 336| Fort Frances
# Processing Record 337| Casa Nova
# Processing Record 338| Kutum
# Processing Record 339| Mercedes
# City not found next ...
# Processing Record 340| Fukuechō
# Processing Record 341| Narsaq
# Processing Record 342| Aripuanã
# Processing Record 343| Gizo Government Station
# Processing Record 344| Mnogovershinnyy
# City not found next ...
# Processing Record 345| Cayenne
# Processing Record 346| Miramar
# Processing Record 347| Banda Aceh
# Processing Record 348| Tieli
# Processing Record 349| Lagoa
# Processing Record 350| Schruns
# Processing Record 351| Houma
# Processing Record 352| Saýat
# Processing Record 353| Acaraú
# Processing Record 354| Tateyama
# Processing Record 355| Labuhan
# Processing Record 356| Leningradskiy
# Processing Record 357| Águia Branca
# Processing Record 358| Roswell
# Processing Record 359| Gēdo
# Processing Record 360| Bako
# Processing Record 361| Severo-Kuril'sk
# Processing Record 362| Mil'kovo
# Processing Record 363| Talnakh
# Processing Record 364| Cabo San Lucas
# Processing Record 365| Mtimbira
# Processing Record 366| Lavrentiya
# Processing Record 367| Paita
# Processing Record 368| Calbuco
# Processing Record 369| Hurghada
# Processing Record 370| Banjar
# City not found next ...
# Processing Record 371| Keti Bandar
# Processing Record 372| Aktau
# Processing Record 373| Kruisfontein
# Processing Record 374| Fairbanks
# Processing Record 375| Kungurtug
# Processing Record 376| Micheweni
# Processing Record 377| Turka
# Processing Record 378| Kochi
# Processing Record 379| Vestmannaeyjar
# Processing Record 380| Kulhudhuffushi
# Processing Record 381| Sibolga
# Processing Record 382| Constitución
# Processing Record 383| Safi
# Processing Record 384| Smithers
# Processing Record 385| Kismayo
# Processing Record 386| Waipawa
# Processing Record 387| Qaqortoq
# Processing Record 388| Trelew
# Processing Record 389| Atherton
# Processing Record 390| Adrar
# Processing Record 391| Boone
# Processing Record 392| Tautira
# Processing Record 393| Buenos Aires
# Processing Record 394| Bria
# Processing Record 395| Carovigno
# Processing Record 396| Oyama
# City not found next ...
# Processing Record 397| Filimonovo
# Processing Record 398| Jacqueville
# Processing Record 399| Homer
# City not found next ...
# Processing Record 400| Miles City
# Processing Record 401| Maniitsoq
# Processing Record 402| Nanortalik
# Processing Record 403| Balaipungut
# Processing Record 404| Coatzacoalcos
# Processing Record 405| Cap-aux-Meules
# Processing Record 406| Bilibino
# Processing Record 407| Acapulco de Juárez
# Processing Record 408| Kloulklubed
# Processing Record 409| Bathsheba
# Processing Record 410| Marsá Maţrūḩ
# Processing Record 411| Praia
# Processing Record 412| Xiongzhou
# Processing Record 413| Muros
# City not found next ...
# Processing Record 414| Barentu
# City not found next ...
# Processing Record 415| Malinyi
# Processing Record 416| La Esperanza
# Processing Record 417| Gamboula
# Processing Record 418| Queimadas
# Processing Record 419| Nishihara
# Processing Record 420| Ulaangom
# Processing Record 421| Coruripe
# Processing Record 422| Awjilah
# Processing Record 423| Egvekinot
# Processing Record 424| Amoy
# Processing Record 425| Itoman
# Processing Record 426| Gambēla
# Processing Record 427| Mackenzie
# Processing Record 428| Chesma
# Processing Record 429| Stornoway
# Processing Record 430| Loa Janan
# Processing Record 431| Hervey Bay
# Processing Record 432| Arlit
# Processing Record 433| Abhā
# Processing Record 434| Rosario
# Processing Record 435| Zabaykal'sk
# Processing Record 436| Kailua
# Processing Record 437| Shirokiy
# Processing Record 438| Tsogni
# Processing Record 439| Penzance
# Processing Record 440| Bridlington
# Processing Record 441| Fort Nelson
# Processing Record 442| João Pessoa
# Processing Record 443| Ust-Kuyga
# Processing Record 444| Faanui
# Processing Record 445| Beringovskiy
# City not found next ...
# Processing Record 446| Maxixe
# Processing Record 447| Vardø
# Processing Record 448| Newala
# Processing Record 449| Sola
# Processing Record 450| Port Hedland
# Processing Record 451| Ouadda
# Processing Record 452| Yangi Marg`ilon
# Processing Record 453| Berlevåg
# Processing Record 454| Nicoya
# Processing Record 455| Rosarito
# City not found next ...
# Processing Record 456| Arrondissement de Saint-Denis
# Processing Record 457| Tumarbong
# Processing Record 458| Chiang Mai
# Processing Record 459| Jalu
# Processing Record 460| Buchanan
# Processing Record 461| Wanlaweyn
# Processing Record 462| Sabang
# Processing Record 463| Shimoda
# Processing Record 464| Athabasca
# Processing Record 465| Vostok
# Processing Record 466| Eberswalde
# Processing Record 467| Takoradze
# Processing Record 468| Gao
# Processing Record 469| Udachny
# City not found next ...
# Processing Record 470| Boguchany
# Processing Record 471| Pisco
# Processing Record 472| Corpus Christi
# Processing Record 473| Touros
# Processing Record 474| Wasilla
# Processing Record 475| Walvis Bay
# Processing Record 476| Yecla
# Processing Record 477| Karratha
# Processing Record 478| Meadow Lake
# Processing Record 479| Shambu
# Processing Record 480| Hobyo
# Processing Record 481| Ayagoz
# Processing Record 482| Izumo
# Processing Record 483| Sarangani
# Processing Record 484| Evensk
# Processing Record 485| Wewak
# Processing Record 486| Meiningen
# Processing Record 487| Inuvik
# Processing Record 488| Port Lincoln
# Processing Record 489| Xichang
# Processing Record 490| Vanderhoof
# Processing Record 491| São João da Barra
# Processing Record 492| Tondano
# Processing Record 493| Chegdomyn
# Processing Record 494| Vila
# Processing Record 495| Port Antonio
# Processing Record 496| Puerto del Rosario
# Processing Record 497| Anzio
# Processing Record 498| Mashhad
# City not found next ...
# Processing Record 499| Bhisho
# Processing Record 500| Brae
# Processing Record 501| Tripoli
# Processing Record 502| San Quintín
# Processing Record 503| Cartaya
# Processing Record 504| Shagonar
# City not found next ...
# Processing Record 505| Normandin
# Processing Record 506| Caravelas
# Processing Record 507| Camrose
# Processing Record 508| Brigantine
# Processing Record 509| Nanzhang
# Processing Record 510| San Andrés
# Processing Record 511| Synya
# Processing Record 512| Killam
# Processing Record 513| Raudeberg
# City not found next ...
# Processing Record 514| Sainte-Suzanne
# Processing Record 515| Gushikawa
# Processing Record 516| Khilok
# Processing Record 517| Roald
# Processing Record 518| Hamamatsu
# City not found next ...
# Processing Record 519| Kohima
# Processing Record 520| Mango
# Processing Record 521| Andenes
# City not found next ...
# Processing Record 522| Saint Simons
# Processing Record 523| Camacha
# Processing Record 524| Sørland
# Processing Record 525| Sturgeon Falls
# Processing Record 526| Ostroh
# City not found next ...
# Processing Record 527| Palora
# Processing Record 528| Los Llanos de Aridane
# Processing Record 529| Solnechnyy
# Processing Record 530| Aldan
# Processing Record 531| Katherine
# Processing Record 532| Nekhayevskiy
# Processing Record 533| Casper
# Processing Record 534| Kysyl-Syr
# Processing Record 535| Koumac
# Processing Record 536| Ugoofaaru
# City not found next ...
# Processing Record 537| Whitehorse
# Processing Record 538| Methven
# Processing Record 539| Port-Cartier
# City not found next ...
# Processing Record 540| Nieuw Amsterdam
# Processing Record 541| Owensboro
# Processing Record 542| Kaya
# Processing Record 543| Nhulunbuy
# Processing Record 544| Agirish
# Processing Record 545| Mata
# Processing Record 546| Mishan
# Processing Record 547| Sainte-Maxime
# Processing Record 548| Lorengau
# Processing Record 549| Linxia Chengguanzhen
# Processing Record 550| Tazovsky
# Processing Record 551| Zhangye
# Processing Record 552| Guantánamo
# Processing Record 553| Ulladulla
# Processing Record 554| Katsuura
# Processing Record 555| Cap Malheureux
# Processing Record 556| San Luis
# Processing Record 557| Kargopol'
# Processing Record 558| Conceição do Araguaia
# Processing Record 559| Griffith
# Processing Record 560| Rāzampeta
# Processing Record 561| Polunochnoye
# Processing Record 562| Yulara
# Processing Record 563| Port Macquarie
# Processing Record 564| Martil
# Processing Record 565| Saint-François
# Processing Record 566| Pychas
# Processing Record 567| Verāval
# City not found next ...
# City not found next ...
# Processing Record 568| Suez
# Processing Record 569| Cañete
# Processing Record 570| Santiago del Estero
# City not found next ...
# Processing Record 571| Ixtapa
# Processing Record 572| Örnsköldsvik
# Processing Record 573| Vilyuysk
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame({"City":city_name, "Latitude":latitude, "Longitude":longitude,
    "Maximum Temperature": max_temperature,"Humidity %":humidity, "Cloudiness %": cloudiness
   ,"Wind Speed(mph)": wind_speed,"Country":country,"Date":date})

weather_df
# Out:
#                     City  Latitude  Longitude  Maximum Temperature  \
# 0               Villazón    -22.09     -65.59                 6.32
# 1               Bengkulu     -3.80     102.27                24.33
# 2                  Ancud    -41.87     -73.82                17.00
# 3              Jamestown     42.10     -79.24                19.00
# 4               Hamilton     39.18     -84.53                23.00
# ..                   ...       ...        ...                  ...
# 568               Cañete    -37.80     -73.40                16.56
# 569  Santiago del Estero    -27.80     -64.26                33.89
# 570               Ixtapa     20.70    -105.20                31.00
# 571         Örnsköldsvik     63.29      18.72                 2.00
# 572             Vilyuysk     63.76     121.62               -23.51
#
#      Humidity %  Cloudiness %  Wind Speed(mph) Country                Date
# 0            87           100             4.56      BO 2020-11-07 21:23:10
# 1            86            90             1.97      ID 2020-11-07 21:21:23
# 2            55             0             4.60      CL 2020-11-07 21:23:11
# 3            37             1             3.10      US 2020-11-07 21:21:47
# 4            33             1             2.10      US 2020-11-07 21:23:11
# ..          ...           ...              ...     ...                 ...
# 568          52             0             5.17      CL 2020-11-07 21:24:58
# 569          23             6             3.58      AR 2020-11-07 21:24:58
# 570          52             5             3.60      MX 2020-11-07 21:24:58
# 571          80            79             5.10      SE 2020-11-07 21:24:58
# 572          90            80             1.97      RU 2020-11-07 21:24:59
#
# [573 rows x 9 columns]

# %%
# Output File (CSV)
output_data_file = "../output_data/cities.csv"
weather_df.to_csv(output_data_file)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_humidity_inspected = weather_df.loc[weather_df["Humidity %"] <= 100 , :]
weather_humidity_inspected
# Out:
#                     City  Latitude  Longitude  Maximum Temperature  \
# 0               Villazón    -22.09     -65.59                 6.32
# 1               Bengkulu     -3.80     102.27                24.33
# 2                  Ancud    -41.87     -73.82                17.00
# 3              Jamestown     42.10     -79.24                19.00
# 4               Hamilton     39.18     -84.53                23.00
# ..                   ...       ...        ...                  ...
# 568               Cañete    -37.80     -73.40                16.56
# 569  Santiago del Estero    -27.80     -64.26                33.89
# 570               Ixtapa     20.70    -105.20                31.00
# 571         Örnsköldsvik     63.29      18.72                 2.00
# 572             Vilyuysk     63.76     121.62               -23.51
#
#      Humidity %  Cloudiness %  Wind Speed(mph) Country                Date
# 0            87           100             4.56      BO 2020-11-07 21:23:10
# 1            86            90             1.97      ID 2020-11-07 21:21:23
# 2            55             0             4.60      CL 2020-11-07 21:23:11
# 3            37             1             3.10      US 2020-11-07 21:21:47
# 4            33             1             2.10      US 2020-11-07 21:23:11
# ..          ...           ...              ...     ...                 ...
# 568          52             0             5.17      CL 2020-11-07 21:24:58
# 569          23             6             3.58      AR 2020-11-07 21:24:58
# 570          52             5             3.60      MX 2020-11-07 21:24:58
# 571          80            79             5.10      SE 2020-11-07 21:24:58
# 572          90            80             1.97      RU 2020-11-07 21:24:59
#
# [573 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
weather_high_humidity = weather_df.loc[weather_df["Humidity %"] > 100 , :]
indices_high_humidity = weather_high_humidity.index.values
print(indices_high_humidity)
# Out:
# []

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
weather_df.drop (indices_high_humidity, inplace=True)
weather_df
# Out:
#                     City  Latitude  Longitude  Maximum Temperature  \
# 0               Villazón    -22.09     -65.59                 6.32
# 1               Bengkulu     -3.80     102.27                24.33
# 2                  Ancud    -41.87     -73.82                17.00
# 3              Jamestown     42.10     -79.24                19.00
# 4               Hamilton     39.18     -84.53                23.00
# ..                   ...       ...        ...                  ...
# 568               Cañete    -37.80     -73.40                16.56
# 569  Santiago del Estero    -27.80     -64.26                33.89
# 570               Ixtapa     20.70    -105.20                31.00
# 571         Örnsköldsvik     63.29      18.72                 2.00
# 572             Vilyuysk     63.76     121.62               -23.51
#
#      Humidity %  Cloudiness %  Wind Speed(mph) Country                Date
# 0            87           100             4.56      BO 2020-11-07 21:23:10
# 1            86            90             1.97      ID 2020-11-07 21:21:23
# 2            55             0             4.60      CL 2020-11-07 21:23:11
# 3            37             1             3.10      US 2020-11-07 21:21:47
# 4            33             1             2.10      US 2020-11-07 21:23:11
# ..          ...           ...              ...     ...                 ...
# 568          52             0             5.17      CL 2020-11-07 21:24:58
# 569          23             6             3.58      AR 2020-11-07 21:24:58
# 570          52             5             3.60      MX 2020-11-07 21:24:58
# 571          80            79             5.10      SE 2020-11-07 21:24:58
# 572          90            80             1.97      RU 2020-11-07 21:24:59
#
# [573 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties
from datetime import datetime
plt.scatter(weather_df["Latitude"],weather_df["Maximum Temperature"], facecolors="red", marker="o", edgecolor="black")
plt.title(f"Latitude vs. Temperature on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperature")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/City_Latitude_vs_Max_Temperature.png")

plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

plt.scatter(weather_df["Latitude"],weather_df["Humidity %"],facecolors="blue", marker="o", edgecolor="black")
plt.title(f"Latitude vs. Humidity on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Humididty")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/City_Latitude_vs_Humidity.png")


plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

plt.scatter(weather_df["Latitude"],weather_df["Cloudiness %"],facecolors="green", marker="o", edgecolor="black")
plt.title(f"Latitude vs. Cloudiness on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)
# Save Figure
plt.savefig("../output_data/City_Latitude_vs_Cloudiness.png")


plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

plt.scatter(weather_df["Latitude"],weather_df["Wind Speed(mph)"],facecolors="purple", marker="o", edgecolor="black")
plt.title(f"Latitude vs. Wind Speed on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/City_Latitude_vs_Wind_Speed.png")


plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

#Extraction of Northern Hemisphere Data
northern_hemisphere = weather_df.loc[weather_df["Latitude"]>0]
x_values = northern_hemisphere["Latitude"]
y_values = northern_hemisphere["Maximum Temperature"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Northern Hemisphere Max Temp vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperaure (C)")
plt.grid(True)


# Save Figure
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()
# Out:
# y = -0.6x + 34.13

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

#Extraction of Northern Hemisphere Data
southern_hemisphere = weather_df.loc[weather_df["Latitude"]<0]
x_values = southern_hemisphere["Latitude"]
y_values = southern_hemisphere["Maximum Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Southern Hemisphere - Max Temp vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Maximum Temperaure (C)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")


print(line_eq)
plt.show()
# Out:
# y = 0.28x + 28.16

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

y_values = northern_hemisphere["Humidity %"]
x_values =  northern_hemisphere["Latitude"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Northern Hemisphere Humidity (%) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()
print(rvalue)
# Out:
# y = 0.25x + 65.91
# 0.24918876055167122

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

y_values = southern_hemisphere["Humidity %"]
x_values =  southern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()
# Out:
# y = 0.38x + 75.75

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

y_values = northern_hemisphere["Cloudiness %"]
x_values =  northern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")
plt.title(f"Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()
# Out:
# y = 0.35x + 37.97

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Build Scatter Plot for Each Data Type
# Incorporate Other Graph Properties

y_values = southern_hemisphere["Cloudiness %"]
x_values = southern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")


plt.title(f"Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()
# Out:
# y = 0.57x + 50.24

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = northern_hemisphere["Wind Speed(mph)"]
x_values = northern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")


plt.title(f"Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Northern Hemisphere - WindSpeed(mph)) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()
# Out:
# y = 0.02x + 3.05

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
y_values = southern_hemisphere["Wind Speed(mph)"]
x_values = southern_hemisphere["Latitude"] 

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(x_values.median(),y_values.median()),fontsize=15,color="red")


plt.title(f"Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression  on {datetime.today().date()}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(mph)")
plt.grid(True)

# Save Figure
plt.savefig("../output_data/Southern Hemisphere - WindSpeed(mph)) vs. Latitude Linear Regression.png")

print(line_eq)
plt.show()
# Out:
# y = -0.05x + 3.15
